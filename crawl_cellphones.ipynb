# %%
from selenium import webdriver
from bs4 import BeautifulSoup 
import pandas as pd
import csv
import requests
import time

# Open web automaticly
driver=webdriver.Edge()
url='https://cellphones.com.vn/mobile.html' #Lấy link để mở web tự động
driver.get(url)

# %%
def GetUrl():
    page_s=BeautifulSoup(driver.page_source,"html.parser") #dùng bs4 tải toàn bộ HTML document lên chương trình
    tel_infors=page_s.find_all('div',class_='block-products san-pham-cate')
    div1=tel_infors[0].find_all('div',class_='box-products')
    div2=div1[0].find_all('div',class_='item-product')
    all_prod=[]

    for tel_infor in div2:
        tel_ID=tel_infor.find('a').get('href')
       
        if tel_ID!=None and tel_ID not in all_prod:
            all_prod.append(tel_ID)
        set(all_prod)

    return all_prod

# %%
numPg=3
Url_all=[]
for i in range(numPg):
    #sroll down until found element next button 
    driver.execute_script("arguments[0].scrollIntoView();", driver.find_element_by_xpath("/html/body/div[1]/div/section/div/div[5]/div/a"))
    driver.execute_script("window.scrollBy(0, -150);")
    e=driver.find_element_by_xpath("/html/body/div[1]/div/section/div/div[5]/div/a")
    e.click()
time.sleep(8)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22384\233300660.py:5: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.execute_script("arguments[0].scrollIntoView();", driver.find_element_by_xpath("/html/body/div[1]/div/section/div/div[5]/div/a"))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22384\233300660.py:7: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   e=driver.find_element_by_xpath("/html/body/div[1]/div/section/div/div[5]/div/a")

# %%
Url_all=[]
Url_all =GetUrl()
print(Url_all)
# Out:
# ['https://cellphones.com.vn/iphone-11.html', 'https://cellphones.com.vn/iphone-13-pro-max.html', 'https://cellphones.com.vn/iphone-11-pro-max.html', 'https://cellphones.com.vn/xiaomi-redmi-note-11.html', 'https://cellphones.com.vn/iphone-12-pro-max.html', 'https://cellphones.com.vn/samsung-galaxy-s22-ultra.html', 'https://cellphones.com.vn/nubia-red-magic-7.html', 'https://cellphones.com.vn/xiaomi-redmi-note-11-pro-plus.html', 'https://cellphones.com.vn/samsung-galaxy-s22-plus.html', 'https://cellphones.com.vn/xiaomi-mi-11t.html', 'https://cellphones.com.vn/samsung-galaxy-note-20-ultra-5g.html', 'https://cellphones.com.vn/iphone-13.html', 'https://cellphones.com.vn/iphone-12.html', 'https://cellphones.com.vn/oppo-reno7-z.html', 'https://cellphones.com.vn/tecno-pova-neo.html', 'https://cellphones.com.vn/iphone-11-128gb.html', 'https://cellphones.com.vn/xiaomi-mi-11-lite.html', 'https://cellphones.com.vn/xiaomi-poco-x3-pro.html', 'https://cellphones.com.vn/vivo-t1x.html', 'https://cellphones.com.vn/xiaomi-redmi-note-11-pro.html', 'https://cellphones.com.vn/iphone-se-2022.html', 'https://cellphones.com.vn/samsung-galaxy-a73.html', 'https://cellphones.com.vn/vsmart-aris-8gb.html', 'https://cellphones.com.vn/tecno-pova-2.html', 'https://cellphones.com.vn/xiaomi-redmi-note-11-128gb.html', 'https://cellphones.com.vn/iphone-13-pro.html', 'https://cellphones.com.vn/oppo-reno-7.html', 'https://cellphones.com.vn/asus-rog-phone-5s-512gb.html', 'https://cellphones.com.vn/realme-narzo-50a.html', 'https://cellphones.com.vn/xiaomi-redmi-10-2022.html', 'https://cellphones.com.vn/xiaomi-mi-12.html', 'https://cellphones.com.vn/asus-rog-phone-5.html', 'https://cellphones.com.vn/samsung-galaxy-a13.html', 'https://cellphones.com.vn/oppo-a95.html', 'https://cellphones.com.vn/asus-rog-phone-5s.html', 'https://cellphones.com.vn/tecno-spark-8c.html', 'https://cellphones.com.vn/iphone-12-128gb.html', 'https://cellphones.com.vn/samsung-galaxy-a32.html', 'https://cellphones.com.vn/iphone-13-pro-max-256gb.html', 'https://cellphones.com.vn/nubia-red-magic-6s-pro.html', 'https://cellphones.com.vn/samsung-galaxy-z-flip-3.html', 'https://cellphones.com.vn/oppo-reno-6.html', 'https://cellphones.com.vn/samsung-galaxy-a53.html', 'https://cellphones.com.vn/samsung-galaxy-s21-fe.html', 'https://cellphones.com.vn/iphone-12-mini.html', 'https://cellphones.com.vn/samsung-galaxy-a52s.html', 'https://cellphones.com.vn/samsung-galaxy-a52.html', 'https://cellphones.com.vn/asus-rog-phone-5s-12gb.html', 'https://cellphones.com.vn/xiaomi-redmi-9a.html', 'https://cellphones.com.vn/xiaomi-mi-11t-pro.html', 'https://cellphones.com.vn/realme-gt-neo-3.html', 'https://cellphones.com.vn/nubia-red-magic-6r.html', 'https://cellphones.com.vn/xiaomi-redmi-10-64gb.html', 'https://cellphones.com.vn/xiaomi-redmi-k40.html', 'https://cellphones.com.vn/xiaomi-mi-12-pro.html', 'https://cellphones.com.vn/asus-rog-phone-5s-8gb-128gb.html', 'https://cellphones.com.vn/samsung-galaxy-m52.html', 'https://cellphones.com.vn/tecno-pova-2-6gb-128gb.html']

# %%
with open('test.csv','a',newline='',encoding='utf-8')as file_output:       
        writer=csv.writer(file_output)
        for url in Url_all:

                driver.get(url)
                page_source=BeautifulSoup(driver.page_source,"html.parser")
                div1=page_source.find_all('table',id='tskt')
                #get text of element has tag td in div1
                try:
                        display=div1[0].find_all('th')[23].get_text()
                except IndexError:
                        continue
                name=page_source.find_all('div',class_='box-name__box-product-name')[0].get_text()
                camera_sau=display=div1[0].find_all('th')[5].get_text()
                camera_truoc=display=div1[0].find_all('th')[7].get_text()
                chip=display=div1[0].find_all('th')[9].get_text()
                ram=display=div1[0].find_all('th')[11].get_text()
                rom=display=div1[0].find_all('th')[13].get_text()
                battery=display=div1[0].find_all('th')[15].get_text()
                sim=display=div1[0].find_all('th')[17].get_text()
                hdh=display=div1[0].find_all('th')[19].get_text()
                sl_tmp=page_source.find_all('p',class_='rating-total')
                soluong=sl_tmp[0].get_text()
                soluong=soluong.split(' ')
                soluong=int(soluong[0])
                dgtmp=page_source.find_all('div',class_='chart-vote__box-left')[0].get_text()
                danhgia=dgtmp.split('/')
                danhgia=float(danhgia[0])
                
                nameshop='Cellphones'
                link=url
                brand=name.split(' ')[0]
                try:
                        giatmp=page_source.find_all('p',class_='special-price')[0].get_text()
                        gia=giatmp.replace('₫','')
                        gia=int(gia.replace('.',''))
                except AttributeError:
                        giatmp=page_source.find_all('p',class_='old-price')[0].get_text()
                        gia=giatmp.replace('₫','')
                        gia=int(gia.replace('.',''))
                        writer.writerow([name,brand,camera_sau,camera_truoc,chip,ram,rom,sim,battery,soluong,danhgia,link,nameshop])
                except IndexError:
                        continue
                brand=brand.strip()
                name=name.strip()
                writer.writerow([name,brand,display,hdh,camera_sau,camera_truoc,chip,ram,rom,sim,battery,gia,danhgia,soluong,link,nameshop])
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# d:\VISUAL\python\CrawlDataFromWeb\crawl_cellphones.ipynb Cell 5' in <module>
#       <a href='vscode-notebook-cell:/d%3A/VISUAL/python/CrawlDataFromWeb/crawl_cellphones.ipynb#ch0000004?line=1'>2</a> writer=csv.writer(file_output)
#       <a href='vscode-notebook-cell:/d%3A/VISUAL/python/CrawlDataFromWeb/crawl_cellphones.ipynb#ch0000004?line=2'>3</a> for url in Url_all:
# ----> <a href='vscode-notebook-cell:/d%3A/VISUAL/python/CrawlDataFromWeb/crawl_cellphones.ipynb#ch0000004?line=4'>5</a>         driver.get(url)
#       <a href='vscode-notebook-cell:/d%3A/VISUAL/python/CrawlDataFromWeb/crawl_cellphones.ipynb#ch0000004?line=5'>6</a>         page_source=BeautifulSoup(driver.page_source,"html.parser")
#       <a href='vscode-notebook-cell:/d%3A/VISUAL/python/CrawlDataFromWeb/crawl_cellphones.ipynb#ch0000004?line=6'>7</a>         div1=page_source.find_all('table',id='tskt')
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:437, in WebDriver.get(self, url)
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=432'>433</a> def get(self, url: str) -> None:
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=433'>434</a>     """
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=434'>435</a>     Loads a web page in the current browser session.
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=435'>436</a>     """
# --> <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=436'>437</a>     self.execute(Command.GET, {'url': url})
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:425, in WebDriver.execute(self, driver_command, params)
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=422'>423</a> response = self.command_executor.execute(driver_command, params)
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=423'>424</a> if response:
# --> <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=424'>425</a>     self.error_handler.check_response(response)
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=425'>426</a>     response['value'] = self._unwrap_value(
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=426'>427</a>         response.get('value', None))
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=427'>428</a>     return response
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/selenium/webdriver/remote/errorhandler.py?line=244'>245</a>         alert_text = value['alert'].get('text')
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/selenium/webdriver/remote/errorhandler.py?line=245'>246</a>     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/selenium/webdriver/remote/errorhandler.py?line=246'>247</a> raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: chrome not reachable
#   (Session info: MicrosoftEdge=101.0.1210.53)
# Stacktrace:
# Backtrace:
# 	Microsoft::Applications::Events::EventProperties::unpack [0x00007FF6C003CC22+24658]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00007FF6BFF7D312+539986]
# 	Ordinal0 [0x00007FF6BFA80DBB+658875]
# 	Ordinal0 [0x00007FF6BFA70052+589906]
# 	Ordinal0 [0x00007FF6BFA709F5+592373]
# 	Ordinal0 [0x00007FF6BFA728DD+600285]
# 	Ordinal0 [0x00007FF6BFA6B08F+569487]
# 	Ordinal0 [0x00007FF6BFA822C1+664257]
# 	Ordinal0 [0x00007FF6BFAEB04D+1093709]
# 	Ordinal0 [0x00007FF6BFAD74B3+1012915]
# 	Ordinal0 [0x00007FF6BFAAE440+844864]
# 	Ordinal0 [0x00007FF6BFAAF848+849992]
# 	Microsoft::Applications::Events::EventProperty::EventProperty [0x00007FF6BFD417D8+120584]
# 	Microsoft::Applications::Events::EventProperty::EventProperty [0x00007FF6BFD2CE1E+36174]
# 	Microsoft::Applications::Events::EventProperty::EventProperty [0x00007FF6BFD3001C+48972]
# 	Microsoft::Applications::Events::EventProperty::to_string [0x00007FF6BFB80716+30806]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00007FF6BFF845E1+569377]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00007FF6BFF89014+588372]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00007FF6BFF8916D+588717]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00007FF6BFF928FE+627518]
# 	BaseThreadInitThunk [0x00007FFC61987034+20]
# 	RtlUserThreadStart [0x00007FFC62FE2651+33]

# %%
df=pd.read_csv('dt3.csv')
df
# Out:
#                                              Name    Brand  \
# 0    Điện thoại Samsung Galaxy S22 Ultra 5G 128GB  Samsung
# 1                       Điện thoại iPhone 11 64GB   iPhone
# 2                      Điện thoại OPPO Reno7 Z 5G     OPPO
# 3                      Điện thoại Realme C35 64GB   Realme
# 4                  Điện thoại Xiaomi 11T 5G 128GB   Xiaomi
# ..                                            ...      ...
# 213                             Nubia Red Magic 6    Nubia
# 214                                      Oppo A16      NaN
# 215                      Xiaomi POCO X3 NFC 128GB   Xiaomi
# 216                                      OPPO A15     OPPO
# 217                                    OPPO Reno5     OPPO
#
#                                    Display                                HDH  \
# 0    Dynamic AMOLED 2X,6.8",Quad HD+ (2K+)                         Android 12
# 1               IPS LCD,6.1",Liquid Retina                             iOS 15
# 2                    AMOLED,6.43",Full HD+                         Android 11
# 3                    IPS LCD,6.6",Full HD+                         Android 11
# 4                    AMOLED,6.67",Full HD+                         Android 11
# ..                                     ...                                ...
# 213               Android 11, Redmagic 4.0           Android 11, Redmagic 4.0
# 214               Android 11, ColorOS 11.1           Android 11, ColorOS 11.1
# 215                    Android 10, MIUI 12                Android 10, MIUI 12
# 216                             Android 10                         Android 10
# 217      ColorOS 11.1, Nền tảng Android 11  ColorOS 11.1, Nền tảng Android 11
#
#                                             Camera sau  \
# 0               Chính 108 MP & Phụ 12 MP, 10 MP, 10 MP
# 1                                       2 camera 12 MP
# 2                         Chính 64 MP & Phụ 2 MP, 2 MP
# 3                       Chính 50 MP & Phụ 2 MP, 0.3 MP
# 4                        Chính 108 MP & Phụ 8 MP, 5 MP
# ..                                                 ...
# 213  Camera chính: 64 MP, f/1.8  Camera góc siêu rộ...
# 214  Camera góc rộng: 13 MP, f/2.2  Camera macro: 2...
# 215  Camera chính: 64 MP, f/1.9, (wide), 1/1.73", 0...
# 216  13 MP, f/2.2, (wide), 1/3.1", 1.12µm, PDAF 2 M...
# 217                         64 MP + 8 MP + 2 MP + 2 MP
#
#                              Camera trước  \
# 0                                   40 MP
# 1                                   12 MP
# 2                                   16 MP
# 3                                    8 MP
# 4                                   16 MP
# ..                                    ...
# 213                            8MP, f/2.0
# 214                           8 MP, f/2.0
# 215   20 MP, f/2.2, (wide), 1/3.4", 0.8µm
# 216                          8 MP, (wide)
# 217  44 MP, F/2.4, Cảm biến thông minh AI
#
#                                           Chip    Ram     Rom  \
# 0                    Snapdragon 8 Gen 1 8 nhân   8 GB  128 GB
# 1                             Apple A13 Bionic   4 GB   64 GB
# 2                     Snapdragon 695 5G 8 nhân   8 GB  128 GB
# 3                           Unisoc T616 8 nhân   4 GB   64 GB
# 4                      MediaTek Dimensity 1200   8 GB  128 GB
# ..                                         ...    ...     ...
# 213                   Snapdragon 888 5G (5 nm)  12 GB  128 GB
# 214                         MediaTek Helio G35   3 GB   32 GB
# 215  Qualcomm SM7150-AC Snapdragon 732G (8 nm)   6 GB  128 GB
# 216           Mediatek MT6765 Helio P35 (12nm)   3 GB   32 GB
# 217    Qualcomm Snapdragon 720G, tối đa 2.3GHz   8 GB  128 GB
#
#                                       Sim                        Battery  \
# 0     2 Nano SIM hoặc 1 Nano SIM + 1 eSIM                       5000 mAh
# 1                     1 Nano SIM & 1 eSIM                       3110 mAh
# 2    2 Nano SIM (SIM 2 chung khe thẻ nhớ)                       4500 mAh
# 3                              2 Nano SIM                       5000 mAh
# 4                              2 Nano SIM                       5000 mAh
# ..                                    ...                            ...
# 213                      2 SIM (Nano-SIM)                  Li-Po 5050mAh
# 214                      2 SIM (Nano-SIM)                 Li-Po 5000 mAh
# 215                      2 SIM (Nano-SIM)   Li-Po 5160 mAh Sạc nhanh 33W
# 216                      2 SIM (Nano-SIM)                 Li-Po 4230 mAh
# 217                      2 SIM (Nano-SIM)  4310mAh (Typ), Sạc siêu nhanh
#
#           Gia  Danh gia  So Luong  \
# 0    30990000       3.0        18
# 1    14990000       4.0       817
# 2    10490000       3.8        81
# 3     3990000       3.5        94
# 4    10990000       3.8       310
# ..        ...       ...       ...
# 213  16990000       5.0         8
# 214   3490000       5.0         0
# 215   5700000       4.5        21
# 216   3290000       4.0         3
# 217   7790000       4.8        26
#
#                                                   Link      Tên cửa hàng
# 0    https://www.thegioididong.com/dtdd/samsung-gal...  Thế giới đi động
# 1    https://www.thegioididong.com/dtdd/iphone-11?s...  Thế giới đi động
# 2    https://www.thegioididong.com/dtdd/oppo-reno7-...  Thế giới đi động
# 3    https://www.thegioididong.com/dtdd/realme-c35?...  Thế giới đi động
# 4    https://www.thegioididong.com/dtdd/xiaomi-11t?...  Thế giới đi động
# ..                                                 ...               ...
# 213   https://cellphones.com.vn/nubia-red-magic-6.html        Cellphones
# 214            https://cellphones.com.vn/oppo-a16.html        Cellphones
# 215      https://cellphones.com.vn/xiaomi-poco-x3.html        Cellphones
# 216            https://cellphones.com.vn/oppo-a15.html        Cellphones
# 217         https://cellphones.com.vn/oppo-reno-5.html        Cellphones
#
# [218 rows x 16 columns]
