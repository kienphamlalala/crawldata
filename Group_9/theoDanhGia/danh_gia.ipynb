# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.offline as pyoff
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
pth = 'most_brn.csv'
df = pd.read_csv(pth)
df
# Out:
#                                     Name    Brand      Gia  Danh gia  \
# 0                    Điện thoại OPPO A95     OPPO  6990000       4.0
# 1              Điện thoại OPPO Reno4 Pro     OPPO  7990000       4.1
# 2   Điện thoại Xiaomi Redmi Note 10S 6GB   Xiaomi  5990000       4.0
# 3                   Xiaomi Mi 11 Lite 5G   Xiaomi  7490000       4.6
# 4           Xiaomi Redmi Note 10 Pro 8GB   Xiaomi  7300000       4.7
# 5                   Xiaomi Redmi Note 10   Xiaomi  5100000       4.7
# 6                    Điện thoại OPPO A76     OPPO  5990000       4.3
# 7                     Samsung Galaxy A71  Samsung  7700000       4.8
# 8                   Điện thoại Vivo Y33s     Vivo  6990000       4.1
# 9                             OPPO Reno5     OPPO  7790000       4.8
# 10              Xiaomi POCO X3 NFC 128GB   Xiaomi  5700000       4.5
# 11          Xiaomi Redmi Note 10 Pro 6GB   Xiaomi  6900000       4.7
# 12                    Samsung Galaxy A31  Samsung  5150000       4.6
# 13                        OPPO Reno4 Pro     OPPO  7990000       5.0
# 14      Xiaomi 11 Lite 5G NE 8GB - 256GB   Xiaomi  7990000       4.0
# 15     Xiaomi Redmi Note 11S 6GB - 128GB   Xiaomi  5390000       5.0
# 16                     Xiaomi Poco X3 GT   Xiaomi  6290000       4.7
# 17                 Vivo V23e 8GB - 128GB     Vivo  7790000       5.0
# 18                    OPPO A76 6GB-128GB     OPPO  5990000       5.0
# 19             Vivo Y53s 8GB+3GB - 128GB     Vivo  5790000       4.0
# 20                       OPPO Reno6 Z 5G     OPPO  7690000       5.0
# 21                 Samsung Galaxy M52 5G  Samsung  7690000       5.0
# 22                          Realme 9 Pro   Realme  6990000       5.0
# 23                 Samsung Galaxy A33 5G  Samsung  7790000       5.0
# 24                    OPPO A95 8GB-128GB     OPPO  6990000       5.0
# 25                 Vivo Y33s 8GB - 128GB     Vivo  6490000       5.0
# 26              Realme 9 Pro 5G 8G-128GB   Realme  7490000       5.0
# 27                    OPPO A94 8GB-128GB     OPPO  5990000       5.0
#
#     So Luong      Tên cửa hàng  \
# 0        263  Thế giới đi động
# 1        143  Thế giới đi động
# 2        121  Thế giới đi động
# 3        107        Cellphones
# 4         52        Cellphones
# 5         51        Cellphones
# 6         47  Thế giới đi động
# 7         36        Cellphones
# 8         32  Thế giới đi động
# 9         26        Cellphones
# 10        21        Cellphones
# 11        15        Cellphones
# 12        11        Cellphones
# 13        11        Cellphones
# 14         9      Cửa hàng FPT
# 15         4      Cửa hàng FPT
# 16         3        Cellphones
# 17         2      Cửa hàng FPT
# 18         2      Cửa hàng FPT
# 19         2      Cửa hàng FPT
# 20         2        Cellphones
# 21         2      Cửa hàng FPT
# 22         1        Cellphones
# 23         1      Cửa hàng FPT
# 24         1      Cửa hàng FPT
# 25         1      Cửa hàng FPT
# 26         1      Cửa hàng FPT
# 27         1      Cửa hàng FPT
#
#                                                  Link
# 0   https://www.thegioididong.com/dtdd/oppo-a95-4g...
# 1   https://www.thegioididong.com/dtdd/oppo-reno4-...
# 2   https://www.thegioididong.com/dtdd/xiaomi-redm...
# 3    https://cellphones.com.vn/xiaomi-mi-11-lite.html
# 4   https://cellphones.com.vn/xiaomi-redmi-note-10...
# 5   https://cellphones.com.vn/xiaomi-redmi-note-10...
# 6   https://www.thegioididong.com/dtdd/oppo-a76-4g...
# 7   https://cellphones.com.vn/samsung-galaxy-a71.html
# 8   https://www.thegioididong.com/dtdd/vivo-y33s?s...
# 9          https://cellphones.com.vn/oppo-reno-5.html
# 10      https://cellphones.com.vn/xiaomi-poco-x3.html
# 11  https://cellphones.com.vn/xiaomi-redmi-note-10...
# 12  https://cellphones.com.vn/samsung-galaxy-a31.html
# 13     https://cellphones.com.vn/oppo-reno-4-pro.html
# 14  https://fptshop.com.vn/dien-thoai/xiaomi-11-li...
# 15  https://fptshop.com.vn/dien-thoai/xiaomi-redmi...
# 16   https://cellphones.com.vn/xiaomi-poco-x3-gt.html
# 17        https://fptshop.com.vn/dien-thoai/vivo-v23e
# 18         https://fptshop.com.vn/dien-thoai/oppo-a76
# 19        https://fptshop.com.vn/dien-thoai/vivo-y53s
# 20        https://cellphones.com.vn/oppo-reno-6z.html
# 21  https://fptshop.com.vn/dien-thoai/samsung-gala...
# 22        https://cellphones.com.vn/realme-9-pro.html
# 23  https://fptshop.com.vn/dien-thoai/samsung-gala...
# 24         https://fptshop.com.vn/dien-thoai/oppo-a95
# 25        https://fptshop.com.vn/dien-thoai/vivo-y33s
# 26     https://fptshop.com.vn/dien-thoai/realme-9-pro
# 27         https://fptshop.com.vn/dien-thoai/oppo-a94

# %%
plot_data = [
    go.Scatter
    (
        x = df['Name'],
        y = df['Danh gia']
    )
]

plot_layout = go.Layout(
    xaxis = {"type":"category"},
    title = "Biểu đồ thể hiện sản phẩm theo đánh giá",
    xaxis_title = 'Tên sản phẩm',
    yaxis_title = 'Đánh giá'
)
fig = go.Figure(data = plot_data , layout = plot_layout)
pyoff.plot(fig)
# Out:
# 'temp-plot.html'

# %%
plot(fig,show_link = True, filename = 'result.html')
# Out:
# 'result.html'
