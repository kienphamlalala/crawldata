# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.offline as pyoff
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
df = pd.read_csv('List_may_hieu_nang_duoi_10tr.csv')
df.head()
# Out:
#                    Name Brand                                      Display  \
# 0    OPPO A95 8GB-128GB  OPPO  6.43 inch, AMOLED, FHD+, 1080 x 2400 Pixels
# 1   Điện thoại OPPO A95  OPPO                        AMOLED,6.43",Full HD+
# 2  Điện thoại Vivo Y33s  Vivo                       IPS LCD,6.58",Full HD+
# 3  Điện thoại Vivo Y53s  Vivo                       IPS LCD,6.58",Full HD+
# 4   Điện thoại OPPO A55  OPPO                             IPS LCD,6.5",HD+
#
#           HDH                    Camera sau Camera trước                Chip  \
# 0  Android 11    48.0 MP + 2.0 MP + 2.0 MP      16.0 MP       Snapdragon 662
# 1  Android 11  Chính 48 MP & Phụ 2 MP, 2 MP        16 MP      Snapdragon 662
# 2  Android 11  Chính 50 MP & Phụ 2 MP, 2 MP        16 MP  MediaTek Helio G80
# 3  Android 11  Chính 64 MP & Phụ 2 MP, 2 MP        16 MP  MediaTek Helio G80
# 4  Android 11  Chính 50 MP & Phụ 2 MP, 2 MP        16 MP  MediaTek Helio G35
#
#     Ram     Rom              Sim   Battery      Gia  Danh gia  So Luong  \
# 0  8 GB  128 GB  2 - 2 Nano SIM   5000 mAh  6990000       5.0         1
# 1  8 GB  128 GB       2 Nano SIM  5000 mAh  6990000       4.0       263
# 2  8 GB  128 GB       2 Nano SIM  5000 mAh  6990000       4.1        32
# 3  8 GB  128 GB       2 Nano SIM  5000 mAh  6990000       2.2        65
# 4  4 GB   64 GB       2 Nano SIM  5000 mAh  4990000       3.6       270
#
#                                                 Link      Tên cửa hàng  \
# 0         https://fptshop.com.vn/dien-thoai/oppo-a95      Cửa hàng FPT
# 1  https://www.thegioididong.com/dtdd/oppo-a95-4g...  Thế giới đi động
# 2  https://www.thegioididong.com/dtdd/vivo-y33s?s...  Thế giới đi động
# 3  https://www.thegioididong.com/dtdd/vivo-y53s?s...  Thế giới đi động
# 4  https://www.thegioididong.com/dtdd/oppo-a55-4g...  Thế giới đi động
#
#    Hieu nang / Gia
# 0        643080000
# 1        643080000
# 2        580170000
# 3        580170000
# 4        558880000

# %%
plot_data = [
    go.Scatter
    (
        x = df['Name'],
        y = df['Hieu nang / Gia']
    )
]

plot_layout = go.Layout(
    xaxis = {"type":"category"},
    title = "Biểu đồ thể hiện sản phẩm theo đánh giá",
    xaxis_title = 'Tên sản phẩm',
    yaxis_title = 'Đánh giá'
)
fig = go.Figure(data = plot_data , layout = plot_layout)
pyoff.plot(fig)
plot(fig,show_link = True, filename = 'result.html')
# Out:
# 'result.html'
